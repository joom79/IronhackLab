# %% [markdown]
# # Sweet vacation #

# %% [markdown]
# This notebook was designed to show the ideal vacation according to a 6-year-old.

# %%
name = input()
print()
# Out:
# Luiza

# %% [markdown]
# ![IMG_9369.jpeg](attachment:IMG_9369.jpeg)

# %% [markdown]
# ![Nea-Chora-Beach-Chania-Crete-allincrete.com-4.jpg](attachment:Nea-Chora-Beach-Chania-Crete-allincrete.com-4.jpg)

# %% [markdown]
# - Eat a lot of ice cream
# - Enjoy the beach all day long
# - visit the old town nearby to have more ice cream

# %%
from IPython.display import YouTubeVideo
video = YouTubeVideo ("kDRSYfdhmg8&t=1s")

# %%
video
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/kDRSYfdhmg8&t=1s"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# According to Luiza, this is the best way to enjoy vacations. :-)
