# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)  #not public, one needs to pay to use it
                                #the APIs return to us dictionary data (key:value)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json() #json: dictionary (no html anynore)
results[0]["title"]
# Out:
# 200
# 'delectus aut autem'

# %%
import pandas as pd
# json to pandas dataframe
pd.DataFrame(results)
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '25422827105',
#   'type': 'WatchEvent',
#   'actor': {'id': 1724660,
#    'login': 'arthureggert',
#    'display_login': 'arthureggert',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/arthureggert',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1724660?'},
#   'repo': {'id': 21911597,
#    'name': 'tayllan/awesome-algorithms',
#    'url': 'https://api.github.com/repos/tayllan/awesome-algorithms'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422827052',
#   'type': 'PushEvent',
#   'actor': {'id': 26503440,
#    'login': 'curtarnolds',
#    'display_login': 'curtarnolds',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/curtarnolds',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26503440?'},
#   'repo': {'id': 538710454,
#    'name': 'curtarnolds/alx-higher_level_programming',
#    'url': 'https://api.github.com/repos/curtarnolds/alx-higher_level_programming'},
#   'payload': {'push_id': 11759323156,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'db3ee644ccd61ed6688e4ea1c6cfa049c80f0543',
#    'before': '7e14868f0544f12f51693742a90ea452d392326a',
#    'commits': [{'sha': 'db3ee644ccd61ed6688e4ea1c6cfa049c80f0543',
#      'author': {'email': 'afayedormawuli@gmail.com', 'name': 'curtarnolds'},
#      'message': 'Inheritance',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/curtarnolds/alx-higher_level_programming/commits/db3ee644ccd61ed6688e4ea1c6cfa049c80f0543'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422827012',
#   'type': 'PushEvent',
#   'actor': {'id': 78800802,
#    'login': 'Sahana-Akter',
#    'display_login': 'Sahana-Akter',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Sahana-Akter',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/78800802?'},
#   'repo': {'id': 569370631,
#    'name': 'Sahana-Akter/Hotel-Booking-in-java-using-File',
#    'url': 'https://api.github.com/repos/Sahana-Akter/Hotel-Booking-in-java-using-File'},
#   'payload': {'push_id': 11759323163,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd161a67915c86f41fa3e07ad3a664d7a343f3aa2',
#    'before': '35c1467f0d3cdfb85575452902f2c446eb026d7b',
#    'commits': [{'sha': 'd161a67915c86f41fa3e07ad3a664d7a343f3aa2',
#      'author': {'email': '78800802+Sahana-Akter@users.noreply.github.com',
#       'name': 'Sahana-Akter'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Sahana-Akter/Hotel-Booking-in-java-using-File/commits/d161a67915c86f41fa3e07ad3a664d7a343f3aa2'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422826993',
#   'type': 'PushEvent',
#   'actor': {'id': 10500630,
#    'login': 'hoangsetup',
#    'display_login': 'hoangsetup',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hoangsetup',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10500630?'},
#   'repo': {'id': 565179989,
#    'name': 'hoangsetup/appsheet-client-api',
#    'url': 'https://api.github.com/repos/hoangsetup/appsheet-client-api'},
#   'payload': {'push_id': 11759323149,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e1da2e415f32017deb5505d8d6566d4dac76456b',
#    'before': '2df73eb9d0360cf1b3288e294d05b7e8835f9d1e',
#    'commits': [{'sha': 'e1da2e415f32017deb5505d8d6566d4dac76456b',
#      'author': {'email': 'hoang.dv@outlook.com', 'name': 'Hoang Dinh'},
#      'message': 'chore: Ignore linting for jest.config.js',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hoangsetup/appsheet-client-api/commits/e1da2e415f32017deb5505d8d6566d4dac76456b'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422827002',
#   'type': 'CreateEvent',
#   'actor': {'id': 116539816,
#    'login': 'cgqvvvvvv',
#    'display_login': 'cgqvvvvvv',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cgqvvvvvv',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/116539816?'},
#   'repo': {'id': 569619483,
#    'name': 'cgqvvvvvv/cgq',
#    'url': 'https://api.github.com/repos/cgqvvvvvv/cgq'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422827004',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 91575249,
#    'name': 'Lombiq/OrchardCore',
#    'url': 'https://api.github.com/repos/Lombiq/OrchardCore'},
#   'payload': {'push_id': 11759323174,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/main',
#    'head': '00742b38ae7ccc7df66f8c5676f06c0f69248914',
#    'before': '00742b38ae7ccc7df66f8c5676f06c0f69248914',
#    'commits': []},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '25422826964',
#   'type': 'CreateEvent',
#   'actor': {'id': 118458657,
#    'login': 'i18n-cms-test',
#    'display_login': 'i18n-cms-test',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/i18n-cms-test',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/118458657?'},
#   'repo': {'id': 569619466,
#    'name': 'i18n-cms-test/mock-setup-repo',
#    'url': 'https://api.github.com/repos/i18n-cms-test/mock-setup-repo'},
#   'payload': {'ref': 'setup/01-branch-with-config',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422826981',
#   'type': 'CreateEvent',
#   'actor': {'id': 99668688,
#    'login': 'ayaashraf14',
#    'display_login': 'ayaashraf14',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ayaashraf14',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99668688?'},
#   'repo': {'id': 569611753,
#    'name': 'ayaashraf14/Shopping-Application',
#    'url': 'https://api.github.com/repos/ayaashraf14/Shopping-Application'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422827001',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 247114159,
#    'name': 'anjamedum/Anja-Medum-CV',
#    'url': 'https://api.github.com/repos/anjamedum/Anja-Medum-CV'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/startbootstrap-resume-gh-pages/engine.io-and-browser-sync-6.2.1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Anja hjemmeside ',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422826973',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 410003328,
#    'name': 'Lombiq/TheClassLessTheme',
#    'url': 'https://api.github.com/repos/Lombiq/TheClassLessTheme'},
#   'payload': {'push_id': 11759323135,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': 'f48a680c245b933ca895411b3831e9d976fc4d0e',
#    'before': 'f48a680c245b933ca895411b3831e9d976fc4d0e',
#    'commits': []},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '25422826961',
#   'type': 'ForkEvent',
#   'actor': {'id': 71868263,
#    'login': 'alok2520',
#    'display_login': 'alok2520',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alok2520',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71868263?'},
#   'repo': {'id': 9419574,
#    'name': 'chkche1/avec2013',
#    'url': 'https://api.github.com/repos/chkche1/avec2013'},
#   'payload': {'forkee': {'id': 569619485,
#     'node_id': 'R_kgDOIfO0HQ',
#     'name': 'avec2013',
#     'full_name': 'alok2520/avec2013',
#     'private': False,
#     'owner': {'login': 'alok2520',
#      'id': 71868263,
#      'node_id': 'MDQ6VXNlcjcxODY4MjYz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/71868263?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/alok2520',
#      'html_url': 'https://github.com/alok2520',
#      'followers_url': 'https://api.github.com/users/alok2520/followers',
#      'following_url': 'https://api.github.com/users/alok2520/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/alok2520/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/alok2520/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/alok2520/subscriptions',
#      'organizations_url': 'https://api.github.com/users/alok2520/orgs',
#      'repos_url': 'https://api.github.com/users/alok2520/repos',
#      'events_url': 'https://api.github.com/users/alok2520/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/alok2520/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/alok2520/avec2013',
#     'description': 'AVEC 2013 Continuous Audio/Visual Emotion and Depression Recognition Challenge',
#     'fork': True,
#     'url': 'https://api.github.com/repos/alok2520/avec2013',
#     'forks_url': 'https://api.github.com/repos/alok2520/avec2013/forks',
#     'keys_url': 'https://api.github.com/repos/alok2520/avec2013/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/alok2520/avec2013/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/alok2520/avec2013/teams',
#     'hooks_url': 'https://api.github.com/repos/alok2520/avec2013/hooks',
#     'issue_events_url': 'https://api.github.com/repos/alok2520/avec2013/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/alok2520/avec2013/events',
#     'assignees_url': 'https://api.github.com/repos/alok2520/avec2013/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/alok2520/avec2013/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/alok2520/avec2013/tags',
#     'blobs_url': 'https://api.github.com/repos/alok2520/avec2013/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/alok2520/avec2013/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/alok2520/avec2013/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/alok2520/avec2013/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/alok2520/avec2013/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/alok2520/avec2013/languages',
#     'stargazers_url': 'https://api.github.com/repos/alok2520/avec2013/stargazers',
#     'contributors_url': 'https://api.github.com/repos/alok2520/avec2013/contributors',
#     'subscribers_url': 'https://api.github.com/repos/alok2520/avec2013/subscribers',
#     'subscription_url': 'https://api.github.com/repos/alok2520/avec2013/subscription',
#     'commits_url': 'https://api.github.com/repos/alok2520/avec2013/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/alok2520/avec2013/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/alok2520/avec2013/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/alok2520/avec2013/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/alok2520/avec2013/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/alok2520/avec2013/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/alok2520/avec2013/merges',
#     'archive_url': 'https://api.github.com/repos/alok2520/avec2013/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/alok2520/avec2013/downloads',
#     'issues_url': 'https://api.github.com/repos/alok2520/avec2013/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/alok2520/avec2013/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/alok2520/avec2013/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/alok2520/avec2013/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/alok2520/avec2013/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/alok2520/avec2013/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/alok2520/avec2013/deployments',
#     'created_at': '2022-11-23T08:39:36Z',
#     'updated_at': '2022-04-01T14:59:06Z',
#     'pushed_at': '2013-05-07T10:26:18Z',
#     'git_url': 'git://github.com/alok2520/avec2013.git',
#     'ssh_url': 'git@github.com:alok2520/avec2013.git',
#     'clone_url': 'https://github.com/alok2520/avec2013.git',
#     'svn_url': 'https://github.com/alok2520/avec2013',
#     'homepage': None,
#     'size': 403,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422826968',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 569124925,
#    'name': 'lazuee/neutralino-template',
#    'url': 'https://api.github.com/repos/lazuee/neutralino-template'},
#   'payload': {'push_id': 11759323134,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '72db60ead3acefbbf4764dfb8220fb0cb37e31cc',
#    'before': 'c37b4d51b1bd01db3e1f60e8fa389d87543347a7',
#    'commits': [{'sha': '72db60ead3acefbbf4764dfb8220fb0cb37e31cc',
#      'author': {'email': 'lazuee.dev@gmail.com', 'name': 'lazuee'},
#      'message': 'New version: 0.1.3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lazuee/neutralino-template/commits/72db60ead3acefbbf4764dfb8220fb0cb37e31cc'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422826905',
#   'type': 'PushEvent',
#   'actor': {'id': 99145179,
#    'login': 'Kawasaki64',
#    'display_login': 'Kawasaki64',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Kawasaki64',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99145179?'},
#   'repo': {'id': 516874820,
#    'name': 'Kawasaki64/honda-v3',
#    'url': 'https://api.github.com/repos/Kawasaki64/honda-v3'},
#   'payload': {'push_id': 11759323105,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b581031ba478131e5a0756054ece3950274a692d',
#    'before': 'c3b115a50eac9e02dddda231a66a64f3149150f4',
#    'commits': [{'sha': 'b581031ba478131e5a0756054ece3950274a692d',
#      'author': {'email': '99145179+Kawasaki64@users.noreply.github.com',
#       'name': 'Kawasaki64'},
#      'message': 'Update usersv3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Kawasaki64/honda-v3/commits/b581031ba478131e5a0756054ece3950274a692d'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422826960',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 5877409,
#    'login': 'lmancel',
#    'display_login': 'lmancel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lmancel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5877409?'},
#   'repo': {'id': 188798279,
#    'name': 'taktik/flowr-desktop',
#    'url': 'https://api.github.com/repos/taktik/flowr-desktop'},
#   'payload': {'action': 'created',
#    'review': {'id': 1191227894,
#     'node_id': 'PRR_kwDOC0DVR85HALH2',
#     'user': {'login': 'lmancel',
#      'id': 5877409,
#      'node_id': 'MDQ6VXNlcjU4Nzc0MDk=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/5877409?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/lmancel',
#      'html_url': 'https://github.com/lmancel',
#      'followers_url': 'https://api.github.com/users/lmancel/followers',
#      'following_url': 'https://api.github.com/users/lmancel/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/lmancel/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/lmancel/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/lmancel/subscriptions',
#      'organizations_url': 'https://api.github.com/users/lmancel/orgs',
#      'repos_url': 'https://api.github.com/users/lmancel/repos',
#      'events_url': 'https://api.github.com/users/lmancel/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/lmancel/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'commit_id': '4c3cfdd8924ff83dffa6fbead1c813320c7ca3cd',
#     'submitted_at': '2022-11-23T08:39:37Z',
#     'state': 'commented',
#     'html_url': 'https://github.com/taktik/flowr-desktop/pull/58#pullrequestreview-1191227894',
#     'pull_request_url': 'https://api.github.com/repos/taktik/flowr-desktop/pulls/58',
#     'author_association': 'NONE',
#     '_links': {'html': {'href': 'https://github.com/taktik/flowr-desktop/pull/58#pullrequestreview-1191227894'},
#      'pull_request': {'href': 'https://api.github.com/repos/taktik/flowr-desktop/pulls/58'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/taktik/flowr-desktop/pulls/58',
#     'id': 1131802171,
#     'node_id': 'PR_kwDOC0DVR85Dde47',
#     'html_url': 'https://github.com/taktik/flowr-desktop/pull/58',
#     'diff_url': 'https://github.com/taktik/flowr-desktop/pull/58.diff',
#     'patch_url': 'https://github.com/taktik/flowr-desktop/pull/58.patch',
#     'issue_url': 'https://api.github.com/repos/taktik/flowr-desktop/issues/58',
#     'number': 58,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bugfix/chrul 397 more fixes',
#     'user': {'login': 'lmancel',
#      'id': 5877409,
#      'node_id': 'MDQ6VXNlcjU4Nzc0MDk=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/5877409?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/lmancel',
#      'html_url': 'https://github.com/lmancel',
#      'followers_url': 'https://api.github.com/users/lmancel/followers',
#      'following_url': 'https://api.github.com/users/lmancel/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/lmancel/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/lmancel/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/lmancel/subscriptions',
#      'organizations_url': 'https://api.github.com/users/lmancel/orgs',
#      'repos_url': 'https://api.github.com/users/lmancel/repos',
#      'events_url': 'https://api.github.com/users/lmancel/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/lmancel/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2022-11-22T13:31:25Z',
#     'updated_at': '2022-11-23T08:39:37Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '48a2980c85ebfd1fb7f816f968d437ce903746d7',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'Azevedo-Dani',
#       'id': 52595012,
#       'node_id': 'MDQ6VXNlcjUyNTk1MDEy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/52595012?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Azevedo-Dani',
#       'html_url': 'https://github.com/Azevedo-Dani',
#       'followers_url': 'https://api.github.com/users/Azevedo-Dani/followers',
#       'following_url': 'https://api.github.com/users/Azevedo-Dani/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Azevedo-Dani/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Azevedo-Dani/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Azevedo-Dani/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Azevedo-Dani/orgs',
#       'repos_url': 'https://api.github.com/users/Azevedo-Dani/repos',
#       'events_url': 'https://api.github.com/users/Azevedo-Dani/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Azevedo-Dani/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/taktik/flowr-desktop/pulls/58/commits',
#     'review_comments_url': 'https://api.github.com/repos/taktik/flowr-desktop/pulls/58/comments',
#     'review_comment_url': 'https://api.github.com/repos/taktik/flowr-desktop/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/taktik/flowr-desktop/issues/58/comments',
#     'statuses_url': 'https://api.github.com/repos/taktik/flowr-desktop/statuses/4c3cfdd8924ff83dffa6fbead1c813320c7ca3cd',
#     'head': {'label': 'taktik:bugfix/CHRUL-397-more-fixes',
#      'ref': 'bugfix/CHRUL-397-more-fixes',
#      'sha': '4c3cfdd8924ff83dffa6fbead1c813320c7ca3cd',
#      'user': {'login': 'taktik',
#       'id': 7781213,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc3ODEyMTM=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/7781213?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/taktik',
#       'html_url': 'https://github.com/taktik',
#       'followers_url': 'https://api.github.com/users/taktik/followers',
#       'following_url': 'https://api.github.com/users/taktik/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/taktik/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/taktik/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/taktik/subscriptions',
#       'organizations_url': 'https://api.github.com/users/taktik/orgs',
#       'repos_url': 'https://api.github.com/users/taktik/repos',
#       'events_url': 'https://api.github.com/users/taktik/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/taktik/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 188798279,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODg3OTgyNzk=',
#       'name': 'flowr-desktop',
#       'full_name': 'taktik/flowr-desktop',
#       'private': False,
#       'owner': {'login': 'taktik',
#        'id': 7781213,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc3ODEyMTM=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/7781213?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/taktik',
#        'html_url': 'https://github.com/taktik',
#        'followers_url': 'https://api.github.com/users/taktik/followers',
#        'following_url': 'https://api.github.com/users/taktik/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/taktik/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/taktik/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/taktik/subscriptions',
#        'organizations_url': 'https://api.github.com/users/taktik/orgs',
#        'repos_url': 'https://api.github.com/users/taktik/repos',
#        'events_url': 'https://api.github.com/users/taktik/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/taktik/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/taktik/flowr-desktop',
#       'description': 'A privacy-focused, extensible and beautiful web browser',
#       'fork': True,
#       'url': 'https://api.github.com/repos/taktik/flowr-desktop',
#       'forks_url': 'https://api.github.com/repos/taktik/flowr-desktop/forks',
#       'keys_url': 'https://api.github.com/repos/taktik/flowr-desktop/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/taktik/flowr-desktop/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/taktik/flowr-desktop/teams',
#       'hooks_url': 'https://api.github.com/repos/taktik/flowr-desktop/hooks',
#       'issue_events_url': 'https://api.github.com/repos/taktik/flowr-desktop/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/taktik/flowr-desktop/events',
#       'assignees_url': 'https://api.github.com/repos/taktik/flowr-desktop/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/taktik/flowr-desktop/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/taktik/flowr-desktop/tags',
#       'blobs_url': 'https://api.github.com/repos/taktik/flowr-desktop/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/taktik/flowr-desktop/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/taktik/flowr-desktop/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/taktik/flowr-desktop/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/taktik/flowr-desktop/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/taktik/flowr-desktop/languages',
#       'stargazers_url': 'https://api.github.com/repos/taktik/flowr-desktop/stargazers',
#       'contributors_url': 'https://api.github.com/repos/taktik/flowr-desktop/contributors',
#       'subscribers_url': 'https://api.github.com/repos/taktik/flowr-desktop/subscribers',
#       'subscription_url': 'https://api.github.com/repos/taktik/flowr-desktop/subscription',
#       'commits_url': 'https://api.github.com/repos/taktik/flowr-desktop/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/taktik/flowr-desktop/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/taktik/flowr-desktop/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/taktik/flowr-desktop/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/taktik/flowr-desktop/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/taktik/flowr-desktop/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/taktik/flowr-desktop/merges',
#       'archive_url': 'https://api.github.com/repos/taktik/flowr-desktop/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/taktik/flowr-desktop/downloads',
#       'issues_url': 'https://api.github.com/repos/taktik/flowr-desktop/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/taktik/flowr-desktop/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/taktik/flowr-desktop/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/taktik/flowr-desktop/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/taktik/flowr-desktop/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/taktik/flowr-desktop/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/taktik/flowr-desktop/deployments',
#       'created_at': '2019-05-27T07:59:10Z',
#       'updated_at': '2022-01-04T11:15:31Z',
#       'pushed_at': '2022-11-23T07:01:12Z',
#       'git_url': 'git://github.com/taktik/flowr-desktop.git',
#       'ssh_url': 'git@github.com:taktik/flowr-desktop.git',
#       'clone_url': 'https://github.com/taktik/flowr-desktop.git',
#       'svn_url': 'https://github.com/taktik/flowr-desktop',
#       'homepage': '',
#       'size': 10022,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'TypeScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 3,
#       'watchers': 4,
#       'default_branch': 'base'}},
#     'base': {'label': 'taktik:base',
#      'ref': 'base',
#      'sha': 'd0737f91cd5c783876dd605368bab4828926fd98',
#      'user': {'login': 'taktik',
#       'id': 7781213,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc3ODEyMTM=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/7781213?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/taktik',
#       'html_url': 'https://github.com/taktik',
#       'followers_url': 'https://api.github.com/users/taktik/followers',
#       'following_url': 'https://api.github.com/users/taktik/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/taktik/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/taktik/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/taktik/subscriptions',
#       'organizations_url': 'https://api.github.com/users/taktik/orgs',
#       'repos_url': 'https://api.github.com/users/taktik/repos',
#       'events_url': 'https://api.github.com/users/taktik/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/taktik/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 188798279,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODg3OTgyNzk=',
#       'name': 'flowr-desktop',
#       'full_name': 'taktik/flowr-desktop',
#       'private': False,
#       'owner': {'login': 'taktik',
#        'id': 7781213,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc3ODEyMTM=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/7781213?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/taktik',
#        'html_url': 'https://github.com/taktik',
#        'followers_url': 'https://api.github.com/users/taktik/followers',
#        'following_url': 'https://api.github.com/users/taktik/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/taktik/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/taktik/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/taktik/subscriptions',
#        'organizations_url': 'https://api.github.com/users/taktik/orgs',
#        'repos_url': 'https://api.github.com/users/taktik/repos',
#        'events_url': 'https://api.github.com/users/taktik/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/taktik/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/taktik/flowr-desktop',
#       'description': 'A privacy-focused, extensible and beautiful web browser',
#       'fork': True,
#       'url': 'https://api.github.com/repos/taktik/flowr-desktop',
#       'forks_url': 'https://api.github.com/repos/taktik/flowr-desktop/forks',
#       'keys_url': 'https://api.github.com/repos/taktik/flowr-desktop/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/taktik/flowr-desktop/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/taktik/flowr-desktop/teams',
#       'hooks_url': 'https://api.github.com/repos/taktik/flowr-desktop/hooks',
#       'issue_events_url': 'https://api.github.com/repos/taktik/flowr-desktop/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/taktik/flowr-desktop/events',
#       'assignees_url': 'https://api.github.com/repos/taktik/flowr-desktop/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/taktik/flowr-desktop/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/taktik/flowr-desktop/tags',
#       'blobs_url': 'https://api.github.com/repos/taktik/flowr-desktop/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/taktik/flowr-desktop/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/taktik/flowr-desktop/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/taktik/flowr-desktop/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/taktik/flowr-desktop/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/taktik/flowr-desktop/languages',
#       'stargazers_url': 'https://api.github.com/repos/taktik/flowr-desktop/stargazers',
#       'contributors_url': 'https://api.github.com/repos/taktik/flowr-desktop/contributors',
#       'subscribers_url': 'https://api.github.com/repos/taktik/flowr-desktop/subscribers',
#       'subscription_url': 'https://api.github.com/repos/taktik/flowr-desktop/subscription',
#       'commits_url': 'https://api.github.com/repos/taktik/flowr-desktop/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/taktik/flowr-desktop/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/taktik/flowr-desktop/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/taktik/flowr-desktop/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/taktik/flowr-desktop/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/taktik/flowr-desktop/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/taktik/flowr-desktop/merges',
#       'archive_url': 'https://api.github.com/repos/taktik/flowr-desktop/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/taktik/flowr-desktop/downloads',
#       'issues_url': 'https://api.github.com/repos/taktik/flowr-desktop/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/taktik/flowr-desktop/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/taktik/flowr-desktop/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/taktik/flowr-desktop/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/taktik/flowr-desktop/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/taktik/flowr-desktop/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/taktik/flowr-desktop/deployments',
#       'created_at': '2019-05-27T07:59:10Z',
#       'updated_at': '2022-01-04T11:15:31Z',
#       'pushed_at': '2022-11-23T07:01:12Z',
#       'git_url': 'git://github.com/taktik/flowr-desktop.git',
#       'ssh_url': 'git@github.com:taktik/flowr-desktop.git',
#       'clone_url': 'https://github.com/taktik/flowr-desktop.git',
#       'svn_url': 'https://github.com/taktik/flowr-desktop',
#       'homepage': '',
#       'size': 10022,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'TypeScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 3,
#       'watchers': 4,
#       'default_branch': 'base'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/taktik/flowr-desktop/pulls/58'},
#      'html': {'href': 'https://github.com/taktik/flowr-desktop/pull/58'},
#      'issue': {'href': 'https://api.github.com/repos/taktik/flowr-desktop/issues/58'},
#      'comments': {'href': 'https://api.github.com/repos/taktik/flowr-desktop/issues/58/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/taktik/flowr-desktop/pulls/58/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/taktik/flowr-desktop/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/taktik/flowr-desktop/pulls/58/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/taktik/flowr-desktop/statuses/4c3cfdd8924ff83dffa6fbead1c813320c7ca3cd'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z',
#   'org': {'id': 7781213,
#    'login': 'taktik',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/taktik',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7781213?'}},
#  {'id': '25422826918',
#   'type': 'PushEvent',
#   'actor': {'id': 7889624,
#    'login': 'sebastientromp',
#    'display_login': 'sebastientromp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sebastientromp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7889624?'},
#   'repo': {'id': 438692660,
#    'name': 'Zero-to-Heroes/firestone-translations',
#    'url': 'https://api.github.com/repos/Zero-to-Heroes/firestone-translations'},
#   'payload': {'push_id': 11759323111,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/l10n_main',
#    'head': '81289b79d0b90ac25073b40a77d3b3fd16d6b13a',
#    'before': 'cf14a1fb800b01d79a67544ab504ab18b1f1b4b6',
#    'commits': [{'sha': '81289b79d0b90ac25073b40a77d3b3fd16d6b13a',
#      'author': {'email': 'sebastien.tromp@gmail.com',
#       'name': 'Sébastien Tromp'},
#      'message': 'New translations enUS.json (ptBR)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Zero-to-Heroes/firestone-translations/commits/81289b79d0b90ac25073b40a77d3b3fd16d6b13a'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z',
#   'org': {'id': 21222659,
#    'login': 'Zero-to-Heroes',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Zero-to-Heroes',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21222659?'}},
#  {'id': '25422826940',
#   'type': 'IssuesEvent',
#   'actor': {'id': 28519221,
#    'login': 'wyf1992',
#    'display_login': 'wyf1992',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wyf1992',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28519221?'},
#   'repo': {'id': 74297382,
#    'name': 'reactjs/react-transition-group',
#    'url': 'https://api.github.com/repos/reactjs/react-transition-group'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/reactjs/react-transition-group/issues/871',
#     'repository_url': 'https://api.github.com/repos/reactjs/react-transition-group',
#     'labels_url': 'https://api.github.com/repos/reactjs/react-transition-group/issues/871/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/reactjs/react-transition-group/issues/871/comments',
#     'events_url': 'https://api.github.com/repos/reactjs/react-transition-group/issues/871/events',
#     'html_url': 'https://github.com/reactjs/react-transition-group/issues/871',
#     'id': 1461279657,
#     'node_id': 'I_kwDOBG2wJs5XGVup',
#     'number': 871,
#     'title': "During the animation, the '-enter' and '-exit' class names were not removed",
#     'user': {'login': 'wyf1992',
#      'id': 28519221,
#      'node_id': 'MDQ6VXNlcjI4NTE5MjIx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/28519221?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/wyf1992',
#      'html_url': 'https://github.com/wyf1992',
#      'followers_url': 'https://api.github.com/users/wyf1992/followers',
#      'following_url': 'https://api.github.com/users/wyf1992/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/wyf1992/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/wyf1992/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/wyf1992/subscriptions',
#      'organizations_url': 'https://api.github.com/users/wyf1992/orgs',
#      'repos_url': 'https://api.github.com/users/wyf1992/repos',
#      'events_url': 'https://api.github.com/users/wyf1992/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/wyf1992/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2022-11-23T08:37:02Z',
#     'updated_at': '2022-11-23T08:39:36Z',
#     'closed_at': '2022-11-23T08:39:36Z',
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': '> What is the current behavior?\r\n\r\nWhen entering animation\r\n`\r\n  <div  class="*-enter *-enter-active"></div>\r\n`\r\nWhen leaving animation\r\n`\r\n  <div  class="*-exit *-exit-active"></div>\r\n`\r\nThe order of css class names is reversed, resulting in invalid animation\r\n\r\n\r\n\r\n> What is the expected behavior?\r\n\r\nWhen entering animation\r\n`\r\n  <div  class="*-enter-active"></div>\r\n`\r\nWhen leaving animation\r\n`\r\n  <div  class="*-exit-active"></div>\r\n`\r\n\r\n\r\n',
#     'reactions': {'url': 'https://api.github.com/repos/reactjs/react-transition-group/issues/871/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/reactjs/react-transition-group/issues/871/timeline',
#     'performed_via_github_app': None,
#     'state_reason': 'completed'}},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z',
#   'org': {'id': 6412038,
#    'login': 'reactjs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/reactjs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6412038?'}},
#  {'id': '25422826900',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 100340294,
#    'login': 'amitmukati-2604',
#    'display_login': 'amitmukati-2604',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amitmukati-2604',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/100340294?'},
#   'repo': {'id': 95700338,
#    'name': 'kubeflow/training-operator',
#    'url': 'https://api.github.com/repos/kubeflow/training-operator'},
#   'payload': {'action': 'closed',
#    'number': 1692,
#    'pull_request': {'url': 'https://api.github.com/repos/kubeflow/training-operator/pulls/1692',
#     'id': 1127516463,
#     'node_id': 'PR_kwDOBbRFcs5DNIkv',
#     'html_url': 'https://github.com/kubeflow/training-operator/pull/1692',
#     'diff_url': 'https://github.com/kubeflow/training-operator/pull/1692.diff',
#     'patch_url': 'https://github.com/kubeflow/training-operator/pull/1692.patch',
#     'issue_url': 'https://api.github.com/repos/kubeflow/training-operator/issues/1692',
#     'number': 1692,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Adding support for linux/ppc64le in github actions for training-operator',
#     'user': {'login': 'amitmukati-2604',
#      'id': 100340294,
#      'node_id': 'U_kgDOBfsSRg',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/100340294?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/amitmukati-2604',
#      'html_url': 'https://github.com/amitmukati-2604',
#      'followers_url': 'https://api.github.com/users/amitmukati-2604/followers',
#      'following_url': 'https://api.github.com/users/amitmukati-2604/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/amitmukati-2604/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/amitmukati-2604/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/amitmukati-2604/subscriptions',
#      'organizations_url': 'https://api.github.com/users/amitmukati-2604/orgs',
#      'repos_url': 'https://api.github.com/users/amitmukati-2604/repos',
#      'events_url': 'https://api.github.com/users/amitmukati-2604/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/amitmukati-2604/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '<!--  Thanks for sending a pull request! Here are some tips for you:\r\n1. If this is your first time, check our contributor guidelines: https://www.kubeflow.org/docs/about/contributing\r\n2. To know more about Training Operator, check the developer guide:\r\n    https://github.com/kubeflow/training-operator/blob/master/docs/development/developer_guide.md\r\n3. If you want *faster* PR reviews, check how: https://git.k8s.io/community/contributors/guide/pull-requests.md#best-practices-for-faster-reviews\r\n-->\r\n\r\n**What this PR does / why we need it**:\r\n\r\nI have added support for Linux/ppc64le architecture in GitHub actions. using QEMU. It enables the CI for Linux/ppc64le. Please review and merge.\r\n\r\n**Which issue(s) this PR fixes** _(optional, in `Fixes #<issue number>, #<issue number>, ...` format, will close the issue(s) when PR gets merged)_:\r\nFixes #\r\n\r\n**Checklist:**\r\n\r\n- [ ] [Docs](https://www.kubeflow.org/docs/components/training/) included if any changes are user facing\r\n\r\n',
#     'created_at': '2022-11-18T12:36:04Z',
#     'updated_at': '2022-11-23T08:39:36Z',
#     'closed_at': '2022-11-23T08:39:36Z',
#     'merged_at': None,
#     'merge_commit_sha': '3161ee31c78717cb0e121f11c4db2aea001511d8',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'kuizhiqing',
#       'id': 2929527,
#       'node_id': 'MDQ6VXNlcjI5Mjk1Mjc=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/2929527?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kuizhiqing',
#       'html_url': 'https://github.com/kuizhiqing',
#       'followers_url': 'https://api.github.com/users/kuizhiqing/followers',
#       'following_url': 'https://api.github.com/users/kuizhiqing/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kuizhiqing/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kuizhiqing/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kuizhiqing/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kuizhiqing/orgs',
#       'repos_url': 'https://api.github.com/users/kuizhiqing/repos',
#       'events_url': 'https://api.github.com/users/kuizhiqing/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kuizhiqing/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'jinchihe',
#       'id': 13673199,
#       'node_id': 'MDQ6VXNlcjEzNjczMTk5',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/13673199?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jinchihe',
#       'html_url': 'https://github.com/jinchihe',
#       'followers_url': 'https://api.github.com/users/jinchihe/followers',
#       'following_url': 'https://api.github.com/users/jinchihe/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jinchihe/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jinchihe/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jinchihe/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jinchihe/orgs',
#       'repos_url': 'https://api.github.com/users/jinchihe/repos',
#       'events_url': 'https://api.github.com/users/jinchihe/events{/privacy}',
# ...
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 508,
#       'open_issues': 61,
#       'watchers': 1175,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/kubeflow/training-operator/pulls/1692'},
#      'html': {'href': 'https://github.com/kubeflow/training-operator/pull/1692'},
#      'issue': {'href': 'https://api.github.com/repos/kubeflow/training-operator/issues/1692'},
#      'comments': {'href': 'https://api.github.com/repos/kubeflow/training-operator/issues/1692/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/kubeflow/training-operator/pulls/1692/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/kubeflow/training-operator/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/kubeflow/training-operator/pulls/1692/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/kubeflow/training-operator/statuses/30270136b413959bb4c24d8226800df8874fe94c'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': False,
#     'mergeable_state': 'unstable',
#     'merged_by': None,
#     'comments': 4,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 7,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z',
#   'org': {'id': 33164907,
#    'login': 'kubeflow',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/kubeflow',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33164907?'}},
#  {'id': '25422826922',
#   'type': 'PushEvent',
#   'actor': {'id': 53325832,
#    'login': 'harness-automation',
#    'display_login': 'harness-automation',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/harness-automation',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53325832?'},
#   'repo': {'id': 542051405,
#    'name': 'harness-automation/Gitx-automation',
#    'url': 'https://api.github.com/repos/harness-automation/Gitx-automation'},
#   'payload': {'push_id': 11759323115,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/GitX_UNcBV',
#    'head': '4cc611042ebc5af1e986850a16b22380ccfbbef2',
#    'before': '69dd7b646ed2d7a0e73eda5850525d93b068afae',
#    'commits': [{'sha': '4cc611042ebc5af1e986850a16b22380ccfbbef2',
#      'author': {'email': 'automation-platform@harnessioprivate.testinator.com',
#       'name': 'automation-platform'},
#      'message': 'createViaAPI',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/harness-automation/Gitx-automation/commits/4cc611042ebc5af1e986850a16b22380ccfbbef2'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422826889',
#   'type': 'CreateEvent',
#   'actor': {'id': 107666318,
#    'login': 'joyuna',
#    'display_login': 'joyuna',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joyuna',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/107666318?'},
#   'repo': {'id': 557219254,
#    'name': 'ProjectJangTeam/gabojago-project',
#    'url': 'https://api.github.com/repos/ProjectJangTeam/gabojago-project'},
#   'payload': {'ref': 'younga6',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': '가보자GO 프로젝트',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z',
#   'org': {'id': 113251641,
#    'login': 'ProjectJangTeam',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ProjectJangTeam',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/113251641?'}},
#  {'id': '25422826901',
#   'type': 'WatchEvent',
#   'actor': {'id': 13202657,
#    'login': 'tsgx1990',
#    'display_login': 'tsgx1990',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tsgx1990',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13202657?'},
#   'repo': {'id': 22119721,
#    'name': 'k88hudson/git-flight-rules',
#    'url': 'https://api.github.com/repos/k88hudson/git-flight-rules'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422826867',
#   'type': 'PushEvent',
#   'actor': {'id': 99959044,
#    'login': 'v9dev',
#    'display_login': 'v9dev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/v9dev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99959044?'},
#   'repo': {'id': 567786594,
#    'name': 'v9dev/epresslocation',
#    'url': 'https://api.github.com/repos/v9dev/epresslocation'},
#   'payload': {'push_id': 11759323093,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/main',
#    'head': '18788d95b3a9973f3ebe29c702ef1e6dbdadafa7',
#    'before': '96768695c891cea50e3ceaa34ca958517971c653',
#    'commits': [{'sha': '4a62317900e80e957ad6391ecbbb902fb2a1eec5',
#      'author': {'email': 'ijpsingh@outlook.com', 'name': 'jpsingh'},
#      'message': 'Heroku Live',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/v9dev/epresslocation/commits/4a62317900e80e957ad6391ecbbb902fb2a1eec5'},
#     {'sha': '1918191c64803962475632b10bce8cb49515e19a',
#      'author': {'email': 'ijpsingh@outlook.com', 'name': 'jpsingh'},
#      'message': 'Adding the view templates',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/v9dev/epresslocation/commits/1918191c64803962475632b10bce8cb49515e19a'},
#     {'sha': '18788d95b3a9973f3ebe29c702ef1e6dbdadafa7',
#      'author': {'email': 'ijpsingh@outlook.com', 'name': 'jpsingh'},
#      'message': 'Merge github.com:v9dev/epresslocation',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/v9dev/epresslocation/commits/18788d95b3a9973f3ebe29c702ef1e6dbdadafa7'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422826868',
#   'type': 'PushEvent',
#   'actor': {'id': 52566643,
#    'login': 'luoluoTH',
#    'display_login': 'luoluoTH',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/luoluoTH',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52566643?'},
#   'repo': {'id': 495743208,
#    'name': 'luoluoTH/yakit',
#    'url': 'https://api.github.com/repos/luoluoTH/yakit'},
#   'payload': {'push_id': 11759323092,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/luoluo/feature/horizontal-menu',
#    'head': '18e30b42294ac9eda9cd9cc20a8efb18cea22ab8',
#    'before': 'fde8b271747a92f6c72fea175f8f96573a297e4c',
#    'commits': [{'sha': '18e30b42294ac9eda9cd9cc20a8efb18cea22ab8',
#      'author': {'email': '1425735414@qq.com', 'name': 'TangHang123'},
#      'message': '-',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/luoluoTH/yakit/commits/18e30b42294ac9eda9cd9cc20a8efb18cea22ab8'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422826869',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 457536633,
#    'name': 'WhitehawkCEC/statuspage',
#    'url': 'https://api.github.com/repos/WhitehawkCEC/statuspage'},
#   'payload': {'push_id': 11759323084,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f35a10d18b286751d003c28747d6f2b7d3e3dfd0',
#    'before': 'e0271db1810b516afcbbebe934f03cbb70ebe79b',
#    'commits': [{'sha': 'f35a10d18b286751d003c28747d6f2b7d3e3dfd0',
#      'author': {'email': 'whdevops@whitehawk.com', 'name': 'Whitehawk DevOps'},
#      'message': '[Automated] Update Health Check Logs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/WhitehawkCEC/statuspage/commits/f35a10d18b286751d003c28747d6f2b7d3e3dfd0'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z',
#   'org': {'id': 25796117,
#    'login': 'WhitehawkCEC',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/WhitehawkCEC',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25796117?'}},
#  {'id': '25422826857',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 529165440,
#    'name': 'Josh5/test-workflows',
#    'url': 'https://api.github.com/repos/Josh5/test-workflows'},
#   'payload': {'push_id': 11759323095,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/pr-notify_radarr',
#    'head': '4ba6248f43410e97d253962ce7bf6d00a8b606c0',
#    'before': '88b4bc2040bd6c6b5077394ea6f854f9056061ff',
#    'commits': [{'sha': '4ba6248f43410e97d253962ce7bf6d00a8b606c0',
#      'author': {'email': 'Josh5', 'name': 'Josh5@users.noreply.github.com'},
#      'message': '[notify_radarr] v0.0.4',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Josh5/test-workflows/commits/4ba6248f43410e97d253962ce7bf6d00a8b606c0'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422826827',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 400167946,
#    'name': 'liurenjie520/yujing',
#    'url': 'https://api.github.com/repos/liurenjie520/yujing'},
#   'payload': {'push_id': 11759323080,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0be254f7adb9fb65b426b5a1eda1556a28566a38',
#    'before': 'a07d8007ef9e8f0da19b1fb926dabfb2f0e7098d',
#    'commits': [{'sha': '0be254f7adb9fb65b426b5a1eda1556a28566a38',
#      'author': {'email': '1438457833@qq.com', 'name': 'marsggbo211'},
#      'message': 'update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/liurenjie520/yujing/commits/0be254f7adb9fb65b426b5a1eda1556a28566a38'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422826808',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 247088040,
#    'name': 'samir-satpute/Assignment1',
#    'url': 'https://api.github.com/repos/samir-satpute/Assignment1'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/engine.io-and-karma-6.2.1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422826882',
#   'type': 'CreateEvent',
#   'actor': {'id': 47116389,
#    'login': 'TuurvdHave',
#    'display_login': 'TuurvdHave',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TuurvdHave',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47116389?'},
#   'repo': {'id': 569619484,
#    'name': 'TuurvdHave/ViconSaving',
#    'url': 'https://api.github.com/repos/TuurvdHave/ViconSaving'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422826870',
#   'type': 'IssuesEvent',
#   'actor': {'id': 58967325,
#    'login': 'Demozsj',
#    'display_login': 'Demozsj',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Demozsj',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58967325?'},
#   'repo': {'id': 563064388,
#    'name': 'mlcommons/training_results_v2.1',
#    'url': 'https://api.github.com/repos/mlcommons/training_results_v2.1'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/mlcommons/training_results_v2.1/issues/1',
#     'repository_url': 'https://api.github.com/repos/mlcommons/training_results_v2.1',
#     'labels_url': 'https://api.github.com/repos/mlcommons/training_results_v2.1/issues/1/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/mlcommons/training_results_v2.1/issues/1/comments',
#     'events_url': 'https://api.github.com/repos/mlcommons/training_results_v2.1/issues/1/events',
#     'html_url': 'https://github.com/mlcommons/training_results_v2.1/issues/1',
#     'id': 1461282451,
#     'node_id': 'I_kwDOIY-uRM5XGWaT',
#     'number': 1,
#     'title': 'Can I run your code without using Docker？',
#     'user': {'login': 'Demozsj',
#      'id': 58967325,
#      'node_id': 'MDQ6VXNlcjU4OTY3MzI1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/58967325?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Demozsj',
#      'html_url': 'https://github.com/Demozsj',
#      'followers_url': 'https://api.github.com/users/Demozsj/followers',
#      'following_url': 'https://api.github.com/users/Demozsj/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Demozsj/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Demozsj/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Demozsj/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Demozsj/orgs',
#      'repos_url': 'https://api.github.com/users/Demozsj/repos',
#      'events_url': 'https://api.github.com/users/Demozsj/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Demozsj/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2022-11-23T08:39:36Z',
#     'updated_at': '2022-11-23T08:39:36Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': 'Hello, I want to ask for advice. Can I run the provided code without using Docker?',
#     'reactions': {'url': 'https://api.github.com/repos/mlcommons/training_results_v2.1/issues/1/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/mlcommons/training_results_v2.1/issues/1/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None}},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z',
#   'org': {'id': 67760141,
#    'login': 'mlcommons',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/mlcommons',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67760141?'}},
#  {'id': '25422826831',
#   'type': 'CreateEvent',
#   'actor': {'id': 53325832,
#    'login': 'harness-automation',
#    'display_login': 'harness-automation',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/harness-automation',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53325832?'},
#   'repo': {'id': 542051405,
#    'name': 'harness-automation/Gitx-automation',
#    'url': 'https://api.github.com/repos/harness-automation/Gitx-automation'},
#   'payload': {'ref': 'GitX_UNcBV',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'},
#  {'id': '25422826830',
#   'type': 'DeleteEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 247206204,
#    'name': 'brayankj/SearchSongs',
#    'url': 'https://api.github.com/repos/brayankj/SearchSongs'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/karma-6.3.16',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-23T08:39:37Z'}]

# %%
pd.DataFrame(response.json())
# Out:
#              id                    type  \
# 0   25422827105              WatchEvent
# 1   25422827052               PushEvent
# 2   25422827012               PushEvent
# 3   25422826993               PushEvent
# 4   25422827002             CreateEvent
# 5   25422827004               PushEvent
# 6   25422826964             CreateEvent
# 7   25422826981             CreateEvent
# 8   25422827001             CreateEvent
# 9   25422826973               PushEvent
# 10  25422826961               ForkEvent
# 11  25422826968               PushEvent
# 12  25422826905               PushEvent
# 13  25422826960  PullRequestReviewEvent
# 14  25422826918               PushEvent
# 15  25422826940             IssuesEvent
# 16  25422826900        PullRequestEvent
# 17  25422826922               PushEvent
# 18  25422826889             CreateEvent
# 19  25422826901              WatchEvent
# 20  25422826867               PushEvent
# 21  25422826868               PushEvent
# 22  25422826869               PushEvent
# 23  25422826857               PushEvent
# 24  25422826827               PushEvent
# 25  25422826808             CreateEvent
# 26  25422826882             CreateEvent
# 27  25422826870             IssuesEvent
# 28  25422826831             CreateEvent
# 29  25422826830             DeleteEvent
#
#                                                 actor  \
# 0   {'id': 1724660, 'login': 'arthureggert', 'disp...
# 1   {'id': 26503440, 'login': 'curtarnolds', 'disp...
# 2   {'id': 78800802, 'login': 'Sahana-Akter', 'dis...
# 3   {'id': 10500630, 'login': 'hoangsetup', 'displ...
# 4   {'id': 116539816, 'login': 'cgqvvvvvv', 'displ...
# 5   {'id': 8517910, 'login': 'LombiqBot', 'display...
# 6   {'id': 118458657, 'login': 'i18n-cms-test', 'd...
# 7   {'id': 99668688, 'login': 'ayaashraf14', 'disp...
# 8   {'id': 49699333, 'login': 'dependabot[bot]', '...
# 9   {'id': 8517910, 'login': 'LombiqBot', 'display...
# 10  {'id': 71868263, 'login': 'alok2520', 'display...
# 11  {'id': 41898282, 'login': 'github-actions[bot]...
# 12  {'id': 99145179, 'login': 'Kawasaki64', 'displ...
# 13  {'id': 5877409, 'login': 'lmancel', 'display_l...
# 14  {'id': 7889624, 'login': 'sebastientromp', 'di...
# 15  {'id': 28519221, 'login': 'wyf1992', 'display_...
# 16  {'id': 100340294, 'login': 'amitmukati-2604', ...
# 17  {'id': 53325832, 'login': 'harness-automation'...
# 18  {'id': 107666318, 'login': 'joyuna', 'display_...
# 19  {'id': 13202657, 'login': 'tsgx1990', 'display...
# 20  {'id': 99959044, 'login': 'v9dev', 'display_lo...
# 21  {'id': 52566643, 'login': 'luoluoTH', 'display...
# 22  {'id': 41898282, 'login': 'github-actions[bot]...
# 23  {'id': 41898282, 'login': 'github-actions[bot]...
# 24  {'id': 41898282, 'login': 'github-actions[bot]...
# 25  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 26  {'id': 47116389, 'login': 'TuurvdHave', 'displ...
# 27  {'id': 58967325, 'login': 'Demozsj', 'display_...
# 28  {'id': 53325832, 'login': 'harness-automation'...
# 29  {'id': 49699333, 'login': 'dependabot[bot]', '...
#
#                                                  repo  \
# 0   {'id': 21911597, 'name': 'tayllan/awesome-algo...
# 1   {'id': 538710454, 'name': 'curtarnolds/alx-hig...
# 2   {'id': 569370631, 'name': 'Sahana-Akter/Hotel-...
# 3   {'id': 565179989, 'name': 'hoangsetup/appsheet...
# 4   {'id': 569619483, 'name': 'cgqvvvvvv/cgq', 'ur...
# 5   {'id': 91575249, 'name': 'Lombiq/OrchardCore',...
# 6   {'id': 569619466, 'name': 'i18n-cms-test/mock-...
# 7   {'id': 569611753, 'name': 'ayaashraf14/Shoppin...
# 8   {'id': 247114159, 'name': 'anjamedum/Anja-Medu...
# 9   {'id': 410003328, 'name': 'Lombiq/TheClassLess...
# 10  {'id': 9419574, 'name': 'chkche1/avec2013', 'u...
# 11  {'id': 569124925, 'name': 'lazuee/neutralino-t...
# 12  {'id': 516874820, 'name': 'Kawasaki64/honda-v3...
# 13  {'id': 188798279, 'name': 'taktik/flowr-deskto...
# 14  {'id': 438692660, 'name': 'Zero-to-Heroes/fire...
# 15  {'id': 74297382, 'name': 'reactjs/react-transi...
# 16  {'id': 95700338, 'name': 'kubeflow/training-op...
# 17  {'id': 542051405, 'name': 'harness-automation/...
# 18  {'id': 557219254, 'name': 'ProjectJangTeam/gab...
# 19  {'id': 22119721, 'name': 'k88hudson/git-flight...
# 20  {'id': 567786594, 'name': 'v9dev/epresslocatio...
# 21  {'id': 495743208, 'name': 'luoluoTH/yakit', 'u...
# 22  {'id': 457536633, 'name': 'WhitehawkCEC/status...
# 23  {'id': 529165440, 'name': 'Josh5/test-workflow...
# 24  {'id': 400167946, 'name': 'liurenjie520/yujing...
# 25  {'id': 247088040, 'name': 'samir-satpute/Assig...
# 26  {'id': 569619484, 'name': 'TuurvdHave/ViconSav...
# 27  {'id': 563064388, 'name': 'mlcommons/training_...
# 28  {'id': 542051405, 'name': 'harness-automation/...
# 29  {'id': 247206204, 'name': 'brayankj/SearchSong...
#
#                                               payload  public  \
# 0                               {'action': 'started'}    True
# 1   {'push_id': 11759323156, 'size': 1, 'distinct_...    True
# 2   {'push_id': 11759323163, 'size': 1, 'distinct_...    True
# 3   {'push_id': 11759323149, 'size': 1, 'distinct_...    True
# 4   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 5   {'push_id': 11759323174, 'size': 0, 'distinct_...    True
# 6   {'ref': 'setup/01-branch-with-config', 'ref_ty...    True
# 7   {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 8   {'ref': 'dependabot/npm_and_yarn/startbootstra...    True
# 9   {'push_id': 11759323135, 'size': 0, 'distinct_...    True
# 10  {'forkee': {'id': 569619485, 'node_id': 'R_kgD...    True
# 11  {'push_id': 11759323134, 'size': 1, 'distinct_...    True
# 12  {'push_id': 11759323105, 'size': 1, 'distinct_...    True
# 13  {'action': 'created', 'review': {'id': 1191227...    True
# 14  {'push_id': 11759323111, 'size': 1, 'distinct_...    True
# 15  {'action': 'closed', 'issue': {'url': 'https:/...    True
# 16  {'action': 'closed', 'number': 1692, 'pull_req...    True
# 17  {'push_id': 11759323115, 'size': 1, 'distinct_...    True
# 18  {'ref': 'younga6', 'ref_type': 'branch', 'mast...    True
# 19                              {'action': 'started'}    True
# 20  {'push_id': 11759323093, 'size': 3, 'distinct_...    True
# 21  {'push_id': 11759323092, 'size': 1, 'distinct_...    True
# 22  {'push_id': 11759323084, 'size': 1, 'distinct_...    True
# 23  {'push_id': 11759323095, 'size': 1, 'distinct_...    True
# 24  {'push_id': 11759323080, 'size': 1, 'distinct_...    True
# 25  {'ref': 'dependabot/npm_and_yarn/engine.io-and...    True
# 26  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 27  {'action': 'opened', 'issue': {'url': 'https:/...    True
# 28  {'ref': 'GitX_UNcBV', 'ref_type': 'branch', 'm...    True
# 29  {'ref': 'dependabot/npm_and_yarn/karma-6.3.16'...    True
#
#               created_at                                                org
# 0   2022-11-23T08:39:37Z                                                NaN
# 1   2022-11-23T08:39:37Z                                                NaN
# 2   2022-11-23T08:39:37Z                                                NaN
# 3   2022-11-23T08:39:37Z                                                NaN
# 4   2022-11-23T08:39:37Z                                                NaN
# 5   2022-11-23T08:39:37Z  {'id': 8158177, 'login': 'Lombiq', 'gravatar_i...
# 6   2022-11-23T08:39:37Z                                                NaN
# 7   2022-11-23T08:39:37Z                                                NaN
# 8   2022-11-23T08:39:37Z                                                NaN
# 9   2022-11-23T08:39:37Z  {'id': 8158177, 'login': 'Lombiq', 'gravatar_i...
# 10  2022-11-23T08:39:37Z                                                NaN
# 11  2022-11-23T08:39:37Z                                                NaN
# 12  2022-11-23T08:39:37Z                                                NaN
# 13  2022-11-23T08:39:37Z  {'id': 7781213, 'login': 'taktik', 'gravatar_i...
# 14  2022-11-23T08:39:37Z  {'id': 21222659, 'login': 'Zero-to-Heroes', 'g...
# 15  2022-11-23T08:39:37Z  {'id': 6412038, 'login': 'reactjs', 'gravatar_...
# 16  2022-11-23T08:39:37Z  {'id': 33164907, 'login': 'kubeflow', 'gravata...
# 17  2022-11-23T08:39:37Z                                                NaN
# 18  2022-11-23T08:39:37Z  {'id': 113251641, 'login': 'ProjectJangTeam', ...
# 19  2022-11-23T08:39:37Z                                                NaN
# 20  2022-11-23T08:39:37Z                                                NaN
# 21  2022-11-23T08:39:37Z                                                NaN
# 22  2022-11-23T08:39:37Z  {'id': 25796117, 'login': 'WhitehawkCEC', 'gra...
# 23  2022-11-23T08:39:37Z                                                NaN
# 24  2022-11-23T08:39:37Z                                                NaN
# 25  2022-11-23T08:39:37Z                                                NaN
# 26  2022-11-23T08:39:37Z                                                NaN
# 27  2022-11-23T08:39:37Z  {'id': 67760141, 'login': 'mlcommons', 'gravat...
# 28  2022-11-23T08:39:37Z                                                NaN
# 29  2022-11-23T08:39:37Z                                                NaN

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id                    type  public            created_at  \
# 0   25422827105              WatchEvent    True  2022-11-23T08:39:37Z
# 1   25422827052               PushEvent    True  2022-11-23T08:39:37Z
# 2   25422827012               PushEvent    True  2022-11-23T08:39:37Z
# 3   25422826993               PushEvent    True  2022-11-23T08:39:37Z
# 4   25422827002             CreateEvent    True  2022-11-23T08:39:37Z
# 5   25422827004               PushEvent    True  2022-11-23T08:39:37Z
# 6   25422826964             CreateEvent    True  2022-11-23T08:39:37Z
# 7   25422826981             CreateEvent    True  2022-11-23T08:39:37Z
# 8   25422827001             CreateEvent    True  2022-11-23T08:39:37Z
# 9   25422826973               PushEvent    True  2022-11-23T08:39:37Z
# 10  25422826961               ForkEvent    True  2022-11-23T08:39:37Z
# 11  25422826968               PushEvent    True  2022-11-23T08:39:37Z
# 12  25422826905               PushEvent    True  2022-11-23T08:39:37Z
# 13  25422826960  PullRequestReviewEvent    True  2022-11-23T08:39:37Z
# 14  25422826918               PushEvent    True  2022-11-23T08:39:37Z
# 15  25422826940             IssuesEvent    True  2022-11-23T08:39:37Z
# 16  25422826900        PullRequestEvent    True  2022-11-23T08:39:37Z
# 17  25422826922               PushEvent    True  2022-11-23T08:39:37Z
# 18  25422826889             CreateEvent    True  2022-11-23T08:39:37Z
# 19  25422826901              WatchEvent    True  2022-11-23T08:39:37Z
# 20  25422826867               PushEvent    True  2022-11-23T08:39:37Z
# 21  25422826868               PushEvent    True  2022-11-23T08:39:37Z
# 22  25422826869               PushEvent    True  2022-11-23T08:39:37Z
# 23  25422826857               PushEvent    True  2022-11-23T08:39:37Z
# 24  25422826827               PushEvent    True  2022-11-23T08:39:37Z
# 25  25422826808             CreateEvent    True  2022-11-23T08:39:37Z
# 26  25422826882             CreateEvent    True  2022-11-23T08:39:37Z
# 27  25422826870             IssuesEvent    True  2022-11-23T08:39:37Z
# 28  25422826831             CreateEvent    True  2022-11-23T08:39:37Z
# 29  25422826830             DeleteEvent    True  2022-11-23T08:39:37Z
#
#      actor.id          actor.login actor.display_login actor.gravatar_id  \
# 0     1724660         arthureggert        arthureggert
# 1    26503440          curtarnolds         curtarnolds
# 2    78800802         Sahana-Akter        Sahana-Akter
# 3    10500630           hoangsetup          hoangsetup
# 4   116539816            cgqvvvvvv           cgqvvvvvv
# 5     8517910            LombiqBot           LombiqBot
# 6   118458657        i18n-cms-test       i18n-cms-test
# 7    99668688          ayaashraf14         ayaashraf14
# 8    49699333      dependabot[bot]          dependabot
# 9     8517910            LombiqBot           LombiqBot
# 10   71868263             alok2520            alok2520
# 11   41898282  github-actions[bot]      github-actions
# 12   99145179           Kawasaki64          Kawasaki64
# 13    5877409              lmancel             lmancel
# 14    7889624       sebastientromp      sebastientromp
# 15   28519221              wyf1992             wyf1992
# 16  100340294      amitmukati-2604     amitmukati-2604
# 17   53325832   harness-automation  harness-automation
# 18  107666318               joyuna              joyuna
# 19   13202657             tsgx1990            tsgx1990
# 20   99959044                v9dev               v9dev
# 21   52566643             luoluoTH            luoluoTH
# 22   41898282  github-actions[bot]      github-actions
# 23   41898282  github-actions[bot]      github-actions
# 24   41898282  github-actions[bot]      github-actions
# 25   49699333      dependabot[bot]          dependabot
# 26   47116389           TuurvdHave          TuurvdHave
# 27   58967325              Demozsj             Demozsj
# 28   53325832   harness-automation  harness-automation
# 29   49699333      dependabot[bot]          dependabot
#
#                                            actor.url  \
# 0          https://api.github.com/users/arthureggert
# 1           https://api.github.com/users/curtarnolds
# 2          https://api.github.com/users/Sahana-Akter
# 3            https://api.github.com/users/hoangsetup
# 4             https://api.github.com/users/cgqvvvvvv
# 5             https://api.github.com/users/LombiqBot
# 6         https://api.github.com/users/i18n-cms-test
# 7           https://api.github.com/users/ayaashraf14
# 8       https://api.github.com/users/dependabot[bot]
# 9             https://api.github.com/users/LombiqBot
# 10             https://api.github.com/users/alok2520
# 11  https://api.github.com/users/github-actions[bot]
# 12           https://api.github.com/users/Kawasaki64
# 13              https://api.github.com/users/lmancel
# 14       https://api.github.com/users/sebastientromp
# 15              https://api.github.com/users/wyf1992
# 16      https://api.github.com/users/amitmukati-2604
# 17   https://api.github.com/users/harness-automation
# 18               https://api.github.com/users/joyuna
# 19             https://api.github.com/users/tsgx1990
# 20                https://api.github.com/users/v9dev
# 21             https://api.github.com/users/luoluoTH
# 22  https://api.github.com/users/github-actions[bot]
# 23  https://api.github.com/users/github-actions[bot]
# 24  https://api.github.com/users/github-actions[bot]
# 25      https://api.github.com/users/dependabot[bot]
# 26           https://api.github.com/users/TuurvdHave
# 27              https://api.github.com/users/Demozsj
# 28   https://api.github.com/users/harness-automation
# 29      https://api.github.com/users/dependabot[bot]
#
#                                      actor.avatar_url  ...  \
# 0    https://avatars.githubusercontent.com/u/1724660?  ...
# 1   https://avatars.githubusercontent.com/u/26503440?  ...
# 2   https://avatars.githubusercontent.com/u/78800802?  ...
# 3   https://avatars.githubusercontent.com/u/10500630?  ...
# 4   https://avatars.githubusercontent.com/u/116539...  ...
# 5    https://avatars.githubusercontent.com/u/8517910?  ...
# 6   https://avatars.githubusercontent.com/u/118458...  ...
# 7   https://avatars.githubusercontent.com/u/99668688?  ...
# 8   https://avatars.githubusercontent.com/u/49699333?  ...
# 9    https://avatars.githubusercontent.com/u/8517910?  ...
# 10  https://avatars.githubusercontent.com/u/71868263?  ...
# 11  https://avatars.githubusercontent.com/u/41898282?  ...
# 12  https://avatars.githubusercontent.com/u/99145179?  ...
# 13   https://avatars.githubusercontent.com/u/5877409?  ...
# 14   https://avatars.githubusercontent.com/u/7889624?  ...
# 15  https://avatars.githubusercontent.com/u/28519221?  ...
# 16  https://avatars.githubusercontent.com/u/100340...  ...
# 17  https://avatars.githubusercontent.com/u/53325832?  ...
# 18  https://avatars.githubusercontent.com/u/107666...  ...
# 19  https://avatars.githubusercontent.com/u/13202657?  ...
# 20  https://avatars.githubusercontent.com/u/99959044?  ...
# 21  https://avatars.githubusercontent.com/u/52566643?  ...
# 22  https://avatars.githubusercontent.com/u/41898282?  ...
# 23  https://avatars.githubusercontent.com/u/41898282?  ...
# 24  https://avatars.githubusercontent.com/u/41898282?  ...
# 25  https://avatars.githubusercontent.com/u/49699333?  ...
# 26  https://avatars.githubusercontent.com/u/47116389?  ...
# 27  https://avatars.githubusercontent.com/u/58967325?  ...
# 28  https://avatars.githubusercontent.com/u/53325832?  ...
# 29  https://avatars.githubusercontent.com/u/49699333?  ...
#
#     payload.pull_request.rebaseable payload.pull_request.mergeable_state  \
# 0                               NaN                                  NaN
# 1                               NaN                                  NaN
# 2                               NaN                                  NaN
# 3                               NaN                                  NaN
# 4                               NaN                                  NaN
# 5                               NaN                                  NaN
# 6                               NaN                                  NaN
# 7                               NaN                                  NaN
# 8                               NaN                                  NaN
# 9                               NaN                                  NaN
# 10                              NaN                                  NaN
# 11                              NaN                                  NaN
# 12                              NaN                                  NaN
# 13                              NaN                                  NaN
# 14                              NaN                                  NaN
# 15                              NaN                                  NaN
# 16                            False                             unstable
# 17                              NaN                                  NaN
# 18                              NaN                                  NaN
# 19                              NaN                                  NaN
# 20                              NaN                                  NaN
# 21                              NaN                                  NaN
# 22                              NaN                                  NaN
# 23                              NaN                                  NaN
# 24                              NaN                                  NaN
# 25                              NaN                                  NaN
# 26                              NaN                                  NaN
# 27                              NaN                                  NaN
# 28                              NaN                                  NaN
# 29                              NaN                                  NaN
#
#    payload.pull_request.merged_by payload.pull_request.comments  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# 5                             NaN                           NaN
# 6                             NaN                           NaN
# 7                             NaN                           NaN
# 8                             NaN                           NaN
# 9                             NaN                           NaN
# 10                            NaN                           NaN
# 11                            NaN                           NaN
# 12                            NaN                           NaN
# 13                            NaN                           NaN
# 14                            NaN                           NaN
# 15                            NaN                           NaN
# 16                            NaN                           4.0
# 17                            NaN                           NaN
# 18                            NaN                           NaN
# 19                            NaN                           NaN
# 20                            NaN                           NaN
# 21                            NaN                           NaN
# 22                            NaN                           NaN
# 23                            NaN                           NaN
# 24                            NaN                           NaN
# 25                            NaN                           NaN
# 26                            NaN                           NaN
# 27                            NaN                           NaN
# 28                            NaN                           NaN
# 29                            NaN                           NaN
#
#     payload.pull_request.review_comments  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                   0.0
# 17                                   NaN
# 18                                   NaN
# 19                                   NaN
# 20                                   NaN
# 21                                   NaN
# 22                                   NaN
# 23                                   NaN
# 24                                   NaN
# 25                                   NaN
# 26                                   NaN
# 27                                   NaN
# 28                                   NaN
# 29                                   NaN
#
#     payload.pull_request.maintainer_can_modify  payload.pull_request.commits  \
# 0                                          NaN                           NaN
# 1                                          NaN                           NaN
# 2                                          NaN                           NaN
# 3                                          NaN                           NaN
# 4                                          NaN                           NaN
# 5                                          NaN                           NaN
# 6                                          NaN                           NaN
# 7                                          NaN                           NaN
# 8                                          NaN                           NaN
# 9                                          NaN                           NaN
# 10                                         NaN                           NaN
# 11                                         NaN                           NaN
# 12                                         NaN                           NaN
# 13                                         NaN                           NaN
# 14                                         NaN                           NaN
# 15                                         NaN                           NaN
# 16                                       False                           1.0
# 17                                         NaN                           NaN
# 18                                         NaN                           NaN
# 19                                         NaN                           NaN
# 20                                         NaN                           NaN
# 21                                         NaN                           NaN
# 22                                         NaN                           NaN
# 23                                         NaN                           NaN
# 24                                         NaN                           NaN
# 25                                         NaN                           NaN
# 26                                         NaN                           NaN
# 27                                         NaN                           NaN
# 28                                         NaN                           NaN
# 29                                         NaN                           NaN
#
#    payload.pull_request.additions payload.pull_request.deletions  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# 5                             NaN                            NaN
# 6                             NaN                            NaN
# 7                             NaN                            NaN
# 8                             NaN                            NaN
# 9                             NaN                            NaN
# 10                            NaN                            NaN
# 11                            NaN                            NaN
# 12                            NaN                            NaN
# 13                            NaN                            NaN
# 14                            NaN                            NaN
# 15                            NaN                            NaN
# 16                            7.0                            1.0
# 17                            NaN                            NaN
# 18                            NaN                            NaN
# 19                            NaN                            NaN
# 20                            NaN                            NaN
# 21                            NaN                            NaN
# 22                            NaN                            NaN
# 23                            NaN                            NaN
# 24                            NaN                            NaN
# 25                            NaN                            NaN
# 26                            NaN                            NaN
# 27                            NaN                            NaN
# 28                            NaN                            NaN
# 29                            NaN                            NaN
#
#    payload.pull_request.changed_files
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# 10                                NaN
# 11                                NaN
# 12                                NaN
# 13                                NaN
# 14                                NaN
# 15                                NaN
# 16                                1.0
# 17                                NaN
# 18                                NaN
# 19                                NaN
# 20                                NaN
# 21                                NaN
# 22                                NaN
# 23                                NaN
# 24                                NaN
# 25                                NaN
# 26                                NaN
# 27                                NaN
# 28                                NaN
# 29                                NaN
#
# [30 rows x 523 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
#This is an open API:

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.json()                    #IT TELLS ME WHERE IT IS NOW (timestamp: time in seconds since jan1st 1970)
# Out:
# {'message': 'success',
#  'iss_position': {'latitude': '-24.8443', 'longitude': '53.0086'},
#  'timestamp': 1669193090}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack
  ## 52.53370520371973, 13.453475292072312
coordinates = {"lat": 52.53370520371973, "lon": 13.453475292072312}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 404

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312'

# %%
response = requests.get('http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312')

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1650978537,
#   'latitude': 52.53370520371973,
#   'longitude': 13.453475292072312,
#   'passes': 5},
#  'response': [{'duration': 210, 'risetime': 1651022628},
#   {'duration': 580, 'risetime': 1651028180},
#   {'duration': 645, 'risetime': 1651033924},
#   {'duration': 652, 'risetime': 1651039720},
#   {'duration': 639, 'risetime': 1651045522}]}

# %%
from datetime import datetime
datetime.fromtimestamp(1645005884)
# Out:
# datetime.datetime(2022, 2, 16, 11, 4, 44)

# %%
pd.to_datetime(1637772367, unit="s")
# Out:
# Timestamp('2021-11-24 16:46:07')
